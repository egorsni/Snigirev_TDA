# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import homcloud.interface as hc
import matplotlib.patches as patches
import seaborn as sns
import pandas as pd
from numpy import cumsum
import os
import torch
from torch import nn
from torch.utils.data import DataLoader
import numpy as np

sns.set(style="whitegrid", font_scale=1.4)

# %%
import pickle

with open('edt_data/X_train_betti', 'rb') as config_dictionary_file:
 
    # Step 3
    X_train = pickle.load(config_dictionary_file)
 
    # After config_dictionary is read from file
    print(len(X_train))
with open('edt_data/X_test_betti', 'rb') as config_dictionary_file:
    X_test = pickle.load(config_dictionary_file)
 
    print(len(X_test))
    
with open('y_train_edt', 'rb') as config_dictionary_file:
    y_train = pickle.load(config_dictionary_file)
 
    print(len(y_train))

with open('y_test_edt', 'rb') as config_dictionary_file:
    y_test = pickle.load(config_dictionary_file)
 
    print(len(y_test))
# Out:
# 50000
# 10000
# 50000
# 10000

# %%
for im_data in X_train:
    print(im_data.shape)
    print()
# Out:
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# ...
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)
#
# (4, 9)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear = nn.Linear(9, 9, bias=False) # bias это отступ AX + b, b -- bias
        self.W = nn.Linear(180, 50, bias=False)
        
    def forward(self, x):
#         D = torch.Tensor()
#         for direction_data in x:
#             H = self.linear(torch.Tensor(direction_data).T).T
#             H /= H.shape[1]
#             dn = torch.sum(H, dim = 1)
# #             print((self.linear(torch.Tensor(direction_data).T).T).shape, H.shape[1])
# #             D.append(dn)
#             D = torch.cat((D, dn),dim=0)
        x = x.reshape((9,-1))
        D = self.linear(torch.Tensor(x).T).T
        D = torch.reshape(D,(-1,9))
#         print(D)
        D = D.T
#         return torch.softmax(self.W((torch.reshape(torch.softmax(D @ torch.transpose(D, 0, 1), -1) @ D, (-1,1))).T).T, 0)
        probs = self.W((torch.reshape(torch.softmax(D @ torch.transpose(D, 0, 1), -1) @ D, (-1,1))).T).T.reshape((5,10))
        return probs

# %%
model = NeuralNetwork()
print(model)
# Out:
# NeuralNetwork(
#   (linear): Linear(in_features=9, out_features=9, bias=False)
#   (W): Linear(in_features=180, out_features=50, bias=False)
# )

# %%
learning_rate = 1e-3
batch_size = 5
epochs = 5

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
from torch.utils.data import TensorDataset, DataLoader
tensor_x = torch.Tensor(X_train) # transform to torch tensor
tensor_y = torch.Tensor(y_train)
print(tensor_x.shape)

my_dataset = TensorDataset(tensor_x,tensor_y) # create your datset
train_dataloader = DataLoader(my_dataset,batch_size=batch_size, shuffle=True) # create your dataloader

tensor_x = torch.Tensor(X_test) # transform to torch tensor
tensor_y = torch.Tensor(y_test)

my_dataset = TensorDataset(tensor_x,tensor_y) # create your datset
test_dataloader = DataLoader(my_dataset,batch_size=batch_size, shuffle=True) # create your dataloader
# Out:
# torch.Size([50000, 4, 9])

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
#         print(pred.shape, y.shape)
#         print(pred, y)
        loss = loss_fn(pred, y.type(torch.LongTensor))

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y.type(torch.LongTensor)).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.375052  [    0/50000]
# loss: 2.383893  [  500/50000]
# loss: 2.458369  [ 1000/50000]
# loss: 2.367743  [ 1500/50000]
# loss: 2.266901  [ 2000/50000]
# loss: 2.447612  [ 2500/50000]
# loss: 2.140205  [ 3000/50000]
# loss: 2.326428  [ 3500/50000]
# loss: 2.233006  [ 4000/50000]
# loss: 2.306743  [ 4500/50000]
# loss: 2.240368  [ 5000/50000]
# loss: 2.329119  [ 5500/50000]
# loss: 2.232664  [ 6000/50000]
# loss: 2.315346  [ 6500/50000]
# loss: 2.346720  [ 7000/50000]
# loss: 2.304063  [ 7500/50000]
# loss: 2.348684  [ 8000/50000]
# loss: 2.313682  [ 8500/50000]
# loss: 2.326681  [ 9000/50000]
# loss: 2.336279  [ 9500/50000]
# loss: 2.324372  [10000/50000]
# loss: 2.344059  [10500/50000]
# loss: 2.319244  [11000/50000]
# loss: 2.295076  [11500/50000]
# loss: 2.233946  [12000/50000]
# loss: 2.279453  [12500/50000]
# loss: 2.323313  [13000/50000]
# loss: 2.290626  [13500/50000]
# loss: 2.266140  [14000/50000]
# loss: 2.390285  [14500/50000]
# loss: 2.341725  [15000/50000]
# loss: 2.298501  [15500/50000]
# loss: 2.282811  [16000/50000]
# loss: 2.307134  [16500/50000]
# loss: 2.331373  [17000/50000]
# loss: 2.314188  [17500/50000]
# loss: 2.309633  [18000/50000]
# loss: 2.274096  [18500/50000]
# loss: 2.299253  [19000/50000]
# loss: 2.294248  [19500/50000]
# loss: 2.298369  [20000/50000]
# loss: 2.299306  [20500/50000]
# loss: 2.294700  [21000/50000]
# loss: 2.334139  [21500/50000]
# loss: 2.310288  [22000/50000]
# loss: 2.276650  [22500/50000]
# loss: 2.309981  [23000/50000]
# loss: 2.290548  [23500/50000]
# loss: 2.319771  [24000/50000]
# loss: 2.281982  [24500/50000]
# loss: 2.309474  [25000/50000]
# loss: 2.324070  [25500/50000]
# loss: 2.295599  [26000/50000]
# loss: 2.296041  [26500/50000]
# loss: 2.312063  [27000/50000]
# loss: 2.287628  [27500/50000]
# loss: 2.310382  [28000/50000]
# loss: 2.307140  [28500/50000]
# loss: 2.319018  [29000/50000]
# loss: 2.290706  [29500/50000]
# loss: 2.291148  [30000/50000]
# loss: 2.324116  [30500/50000]
# loss: 2.329531  [31000/50000]
# loss: 2.327788  [31500/50000]
# loss: 2.266237  [32000/50000]
# loss: 2.291276  [32500/50000]
# loss: 2.315221  [33000/50000]
# loss: 2.297983  [33500/50000]
# loss: 2.339918  [34000/50000]
# loss: 2.327854  [34500/50000]
# loss: 2.328551  [35000/50000]
# loss: 2.302234  [35500/50000]
# loss: 2.298474  [36000/50000]
# loss: 2.323056  [36500/50000]
# loss: 2.302978  [37000/50000]
# loss: 2.314864  [37500/50000]
# loss: 2.365795  [38000/50000]
# loss: 2.289831  [38500/50000]
# loss: 2.304233  [39000/50000]
# loss: 2.317088  [39500/50000]
# loss: 2.303726  [40000/50000]
# loss: 2.342320  [40500/50000]
# loss: 2.352488  [41000/50000]
# loss: 2.308084  [41500/50000]
# loss: 2.251284  [42000/50000]
# loss: 2.288337  [42500/50000]
# loss: 2.286225  [43000/50000]
# loss: 2.287469  [43500/50000]
# loss: 2.290246  [44000/50000]
# loss: 2.297072  [44500/50000]
# loss: 2.332484  [45000/50000]
# loss: 2.275927  [45500/50000]
# loss: 2.298618  [46000/50000]
# loss: 2.324863  [46500/50000]
# loss: 2.308453  [47000/50000]
# loss: 2.269075  [47500/50000]
# loss: 2.280128  [48000/50000]
# loss: 2.282202  [48500/50000]
# loss: 2.275669  [49000/50000]
# loss: 2.274454  [49500/50000]
# Test Error:
#  Accuracy: 9.8%, Avg loss: 2.303532
#
# Epoch 2
# -------------------------------
# loss: 2.289020  [    0/50000]
# loss: 2.286170  [  500/50000]
# loss: 2.340013  [ 1000/50000]
# loss: 2.328336  [ 1500/50000]
# loss: 2.275859  [ 2000/50000]
# loss: 2.275747  [ 2500/50000]
# loss: 2.276139  [ 3000/50000]
# loss: 2.282455  [ 3500/50000]
# loss: 2.324140  [ 4000/50000]
# loss: 2.326567  [ 4500/50000]
# loss: 2.267873  [ 5000/50000]
# loss: 2.328984  [ 5500/50000]
# loss: 2.279938  [ 6000/50000]
# loss: 2.292573  [ 6500/50000]
# loss: 2.299447  [ 7000/50000]
# loss: 2.307551  [ 7500/50000]
# loss: 2.306549  [ 8000/50000]
# loss: 2.298741  [ 8500/50000]
# loss: 2.342384  [ 9000/50000]
# loss: 2.279077  [ 9500/50000]
# loss: 2.309139  [10000/50000]
# loss: 2.293267  [10500/50000]
# loss: 2.313016  [11000/50000]
# loss: 2.288064  [11500/50000]
# loss: 2.284150  [12000/50000]
# loss: 2.306290  [12500/50000]
# loss: 2.276614  [13000/50000]
# loss: 2.303868  [13500/50000]
# loss: 2.281792  [14000/50000]
# loss: 2.313577  [14500/50000]
# loss: 2.311965  [15000/50000]
# loss: 2.305154  [15500/50000]
# loss: 2.299286  [16000/50000]
# loss: 2.300768  [16500/50000]
# loss: 2.312884  [17000/50000]
# loss: 2.318147  [17500/50000]
# loss: 2.315283  [18000/50000]
# loss: 2.303034  [18500/50000]
# loss: 2.284984  [19000/50000]
# loss: 2.325356  [19500/50000]
# loss: 2.346823  [20000/50000]
# loss: 2.339755  [20500/50000]
# loss: 2.345182  [21000/50000]
# loss: 2.295065  [21500/50000]
# loss: 2.262645  [22000/50000]
# loss: 2.286311  [22500/50000]
# loss: 2.316437  [23000/50000]
# loss: 2.278151  [23500/50000]
# loss: 2.270496  [24000/50000]
# loss: 2.285073  [24500/50000]
# loss: 2.306640  [25000/50000]
# loss: 2.286750  [25500/50000]
# loss: 2.317660  [26000/50000]
# loss: 2.296483  [26500/50000]
# loss: 2.304824  [27000/50000]
# loss: 2.316174  [27500/50000]
# loss: 2.299576  [28000/50000]
# loss: 2.273078  [28500/50000]
# loss: 2.295453  [29000/50000]
# loss: 2.271492  [29500/50000]
# loss: 2.319993  [30000/50000]
# loss: 2.312444  [30500/50000]
# loss: 2.320997  [31000/50000]
# loss: 2.325811  [31500/50000]
# loss: 2.291231  [32000/50000]
# loss: 2.354082  [32500/50000]
# loss: 2.274729  [33000/50000]
# loss: 2.300090  [33500/50000]
# loss: 2.320713  [34000/50000]
# loss: 2.285885  [34500/50000]
# loss: 2.321321  [35000/50000]
# loss: 2.296929  [35500/50000]
# loss: 2.293536  [36000/50000]
# loss: 2.287848  [36500/50000]
# loss: 2.257629  [37000/50000]
# loss: 2.299944  [37500/50000]
# loss: 2.316750  [38000/50000]
# loss: 2.298528  [38500/50000]
# loss: 2.301797  [39000/50000]
# loss: 2.301183  [39500/50000]
# loss: 2.313743  [40000/50000]
# loss: 2.328728  [40500/50000]
# loss: 2.261588  [41000/50000]
# loss: 2.296207  [41500/50000]
# loss: 2.296099  [42000/50000]
# loss: 2.292932  [42500/50000]
# loss: 2.311655  [43000/50000]
# loss: 2.295298  [43500/50000]
# loss: 2.296241  [44000/50000]
# loss: 2.309659  [44500/50000]
# loss: 2.306420  [45000/50000]
# loss: 2.283336  [45500/50000]
# loss: 2.292523  [46000/50000]
# loss: 2.303164  [46500/50000]
# loss: 2.313940  [47000/50000]
# loss: 2.324207  [47500/50000]
# loss: 2.297576  [48000/50000]
# loss: 2.304175  [48500/50000]
# loss: 2.298960  [49000/50000]
# loss: 2.301719  [49500/50000]
# Test Error:
#  Accuracy: 10.3%, Avg loss: 2.303391
#
# Epoch 3
# -------------------------------
# loss: 2.316549  [    0/50000]
# loss: 2.312893  [  500/50000]
# loss: 2.288020  [ 1000/50000]
# loss: 2.285660  [ 1500/50000]
# loss: 2.307619  [ 2000/50000]
# loss: 2.345069  [ 2500/50000]
# loss: 2.316721  [ 3000/50000]
# loss: 2.317204  [ 3500/50000]
# loss: 2.311574  [ 4000/50000]
# loss: 2.315941  [ 4500/50000]
# loss: 2.330145  [ 5000/50000]
# loss: 2.313338  [ 5500/50000]
# loss: 2.293059  [ 6000/50000]
# loss: 2.289759  [ 6500/50000]
# loss: 2.336164  [ 7000/50000]
# loss: 2.325305  [ 7500/50000]
# loss: 2.328394  [ 8000/50000]
# loss: 2.277700  [ 8500/50000]
# loss: 2.315459  [ 9000/50000]
# loss: 2.291422  [ 9500/50000]
# loss: 2.322711  [10000/50000]
# loss: 2.301559  [10500/50000]
# loss: 2.300813  [11000/50000]
# loss: 2.315398  [11500/50000]
# loss: 2.312640  [12000/50000]
# loss: 2.289697  [12500/50000]
# loss: 2.300323  [13000/50000]
# loss: 2.294973  [13500/50000]
# loss: 2.312503  [14000/50000]
# loss: 2.328702  [14500/50000]
# loss: 2.297962  [15000/50000]
# loss: 2.273533  [15500/50000]
# loss: 2.298194  [16000/50000]
# loss: 2.297487  [16500/50000]
# loss: 2.330296  [17000/50000]
# loss: 2.309622  [17500/50000]
# loss: 2.308046  [18000/50000]
# loss: 2.295460  [18500/50000]
# loss: 2.290664  [19000/50000]
# loss: 2.309567  [19500/50000]
# loss: 2.301151  [20000/50000]
# loss: 2.282001  [20500/50000]
# loss: 2.313283  [21000/50000]
# loss: 2.292458  [21500/50000]
# loss: 2.276152  [22000/50000]
# loss: 2.299783  [22500/50000]
# loss: 2.315832  [23000/50000]
# loss: 2.312986  [23500/50000]
# loss: 2.306353  [24000/50000]
# loss: 2.297908  [24500/50000]
# loss: 2.301047  [25000/50000]
# loss: 2.321864  [25500/50000]
# loss: 2.288097  [26000/50000]
# loss: 2.281927  [26500/50000]
# loss: 2.295578  [27000/50000]
# loss: 2.287184  [27500/50000]
# loss: 2.301162  [28000/50000]
# loss: 2.324058  [28500/50000]
# loss: 2.322583  [29000/50000]
# loss: 2.293586  [29500/50000]
# loss: 2.285745  [30000/50000]
# loss: 2.312450  [30500/50000]
# loss: 2.324931  [31000/50000]
# loss: 2.301901  [31500/50000]
# loss: 2.287472  [32000/50000]
# loss: 2.310447  [32500/50000]
# loss: 2.292236  [33000/50000]
# loss: 2.309851  [33500/50000]
# loss: 2.294631  [34000/50000]
# loss: 2.315253  [34500/50000]
# loss: 2.325438  [35000/50000]
# loss: 2.302581  [35500/50000]
# loss: 2.330904  [36000/50000]
# loss: 2.321749  [36500/50000]
# loss: 2.287567  [37000/50000]
# loss: 2.308856  [37500/50000]
# loss: 2.321326  [38000/50000]
# loss: 2.307178  [38500/50000]
# loss: 2.269326  [39000/50000]
# loss: 2.287330  [39500/50000]
# loss: 2.259862  [40000/50000]
# loss: 2.262785  [40500/50000]
# loss: 2.336542  [41000/50000]
# loss: 2.327130  [41500/50000]
# loss: 2.319042  [42000/50000]
# loss: 2.305592  [42500/50000]
# loss: 2.313259  [43000/50000]
# loss: 2.325156  [43500/50000]
# loss: 2.288164  [44000/50000]
# loss: 2.302764  [44500/50000]
# loss: 2.320842  [45000/50000]
# loss: 2.314491  [45500/50000]
# loss: 2.319333  [46000/50000]
# loss: 2.323083  [46500/50000]
# loss: 2.308222  [47000/50000]
# loss: 2.298995  [47500/50000]
# loss: 2.279162  [48000/50000]
# loss: 2.324570  [48500/50000]
# loss: 2.299538  [49000/50000]
# loss: 2.298858  [49500/50000]
# Test Error:
#  Accuracy: 10.1%, Avg loss: 2.302786
#
# Epoch 4
# -------------------------------
# loss: 2.293831  [    0/50000]
# loss: 2.316244  [  500/50000]
# loss: 2.291214  [ 1000/50000]
# loss: 2.322596  [ 1500/50000]
# loss: 2.285436  [ 2000/50000]
# loss: 2.298818  [ 2500/50000]
# loss: 2.308352  [ 3000/50000]
# loss: 2.271893  [ 3500/50000]
# loss: 2.312675  [ 4000/50000]
# loss: 2.327171  [ 4500/50000]
# loss: 2.327642  [ 5000/50000]
# loss: 2.282157  [ 5500/50000]
# loss: 2.284000  [ 6000/50000]
# loss: 2.305789  [ 6500/50000]
# loss: 2.312677  [ 7000/50000]
# loss: 2.287536  [ 7500/50000]
# loss: 2.293824  [ 8000/50000]
# loss: 2.310969  [ 8500/50000]
# loss: 2.290746  [ 9000/50000]
# loss: 2.288375  [ 9500/50000]
# loss: 2.282104  [10000/50000]
# loss: 2.269160  [10500/50000]
# loss: 2.324523  [11000/50000]
# loss: 2.299580  [11500/50000]
# loss: 2.310396  [12000/50000]
# loss: 2.297269  [12500/50000]
# loss: 2.285800  [13000/50000]
# loss: 2.302186  [13500/50000]
# loss: 2.318418  [14000/50000]
# loss: 2.324733  [14500/50000]
# loss: 2.299428  [15000/50000]
# loss: 2.270673  [15500/50000]
# loss: 2.300849  [16000/50000]
# loss: 2.270020  [16500/50000]
# loss: 2.266574  [17000/50000]
# loss: 2.321851  [17500/50000]
# loss: 2.297401  [18000/50000]
# loss: 2.328135  [18500/50000]
# loss: 2.283609  [19000/50000]
# loss: 2.314011  [19500/50000]
# loss: 2.315584  [20000/50000]
# loss: 2.330384  [20500/50000]
# loss: 2.289446  [21000/50000]
# loss: 2.293451  [21500/50000]
# loss: 2.306324  [22000/50000]
# loss: 2.288389  [22500/50000]
# loss: 2.314348  [23000/50000]
# loss: 2.324183  [23500/50000]
# loss: 2.318063  [24000/50000]
# loss: 2.294923  [24500/50000]
# loss: 2.293403  [25000/50000]
# loss: 2.287918  [25500/50000]
# loss: 2.297657  [26000/50000]
# loss: 2.340988  [26500/50000]
# loss: 2.302430  [27000/50000]
# loss: 2.297020  [27500/50000]
# loss: 2.315992  [28000/50000]
# loss: 2.288493  [28500/50000]
# loss: 2.288072  [29000/50000]
# loss: 2.317151  [29500/50000]
# loss: 2.324864  [30000/50000]
# loss: 2.300773  [30500/50000]
# loss: 2.306337  [31000/50000]
# loss: 2.315096  [31500/50000]
# loss: 2.282495  [32000/50000]
# loss: 2.263730  [32500/50000]
# loss: 2.298009  [33000/50000]
# loss: 2.293311  [33500/50000]
# loss: 2.317654  [34000/50000]
# loss: 2.286636  [34500/50000]
# loss: 2.282665  [35000/50000]
# loss: 2.312010  [35500/50000]
# loss: 2.305016  [36000/50000]
# loss: 2.330777  [36500/50000]
# loss: 2.328925  [37000/50000]
# loss: 2.286859  [37500/50000]
# loss: 2.303801  [38000/50000]
# loss: 2.317460  [38500/50000]
# loss: 2.303508  [39000/50000]
# loss: 2.291987  [39500/50000]
# loss: 2.293175  [40000/50000]
# loss: 2.300734  [40500/50000]
# loss: 2.300010  [41000/50000]
# loss: 2.325245  [41500/50000]
# loss: 2.304183  [42000/50000]
# loss: 2.297224  [42500/50000]
# loss: 2.301472  [43000/50000]
# loss: 2.315500  [43500/50000]
# loss: 2.324615  [44000/50000]
# loss: 2.274256  [44500/50000]
# loss: 2.300231  [45000/50000]
# loss: 2.327797  [45500/50000]
# loss: 2.309069  [46000/50000]
# loss: 2.300519  [46500/50000]
# loss: 2.288034  [47000/50000]
# loss: 2.296247  [47500/50000]
# loss: 2.305804  [48000/50000]
# loss: 2.289994  [48500/50000]
# loss: 2.317258  [49000/50000]
# loss: 2.334767  [49500/50000]
# Test Error:
#  Accuracy: 9.6%, Avg loss: 2.302930
#
# Epoch 5
# -------------------------------
# loss: 2.315090  [    0/50000]
# loss: 2.318694  [  500/50000]
# loss: 2.295691  [ 1000/50000]
# loss: 2.304680  [ 1500/50000]
# loss: 2.286737  [ 2000/50000]
# loss: 2.289936  [ 2500/50000]
# loss: 2.318096  [ 3000/50000]
# loss: 2.314106  [ 3500/50000]
# loss: 2.296153  [ 4000/50000]
# loss: 2.303010  [ 4500/50000]
# loss: 2.316448  [ 5000/50000]
# loss: 2.285948  [ 5500/50000]
# loss: 2.320725  [ 6000/50000]
# loss: 2.321469  [ 6500/50000]
# loss: 2.296115  [ 7000/50000]
# loss: 2.315143  [ 7500/50000]
# loss: 2.297343  [ 8000/50000]
# loss: 2.303951  [ 8500/50000]
# loss: 2.312197  [ 9000/50000]
# loss: 2.318054  [ 9500/50000]
# loss: 2.330842  [10000/50000]
# loss: 2.320899  [10500/50000]
# loss: 2.307130  [11000/50000]
# loss: 2.318048  [11500/50000]
# loss: 2.310414  [12000/50000]
# loss: 2.318873  [12500/50000]
# loss: 2.287130  [13000/50000]
# loss: 2.301670  [13500/50000]
# loss: 2.313627  [14000/50000]
# loss: 2.313926  [14500/50000]
# loss: 2.284402  [15000/50000]
# loss: 2.301039  [15500/50000]
# loss: 2.311843  [16000/50000]
# loss: 2.288324  [16500/50000]
# loss: 2.317422  [17000/50000]
# loss: 2.280722  [17500/50000]
# loss: 2.314715  [18000/50000]
# loss: 2.294526  [18500/50000]
# loss: 2.298551  [19000/50000]
# loss: 2.303882  [19500/50000]
# loss: 2.322629  [20000/50000]
# loss: 2.285846  [20500/50000]
# loss: 2.296334  [21000/50000]
# loss: 2.296720  [21500/50000]
# loss: 2.290197  [22000/50000]
# loss: 2.303810  [22500/50000]
# loss: 2.297883  [23000/50000]
# loss: 2.318429  [23500/50000]
# loss: 2.303190  [24000/50000]
# loss: 2.295889  [24500/50000]
# loss: 2.314843  [25000/50000]
# loss: 2.303553  [25500/50000]
# loss: 2.291687  [26000/50000]
# loss: 2.297572  [26500/50000]
# loss: 2.306250  [27000/50000]
# loss: 2.287246  [27500/50000]
# loss: 2.293219  [28000/50000]
# loss: 2.304631  [28500/50000]
# loss: 2.311240  [29000/50000]
# loss: 2.298888  [29500/50000]
# loss: 2.308050  [30000/50000]
# loss: 2.315743  [30500/50000]
# loss: 2.286757  [31000/50000]
# loss: 2.291283  [31500/50000]
# loss: 2.304888  [32000/50000]
# loss: 2.296822  [32500/50000]
# loss: 2.286304  [33000/50000]
# loss: 2.304876  [33500/50000]
# loss: 2.321476  [34000/50000]
# loss: 2.318964  [34500/50000]
# loss: 2.288893  [35000/50000]
# loss: 2.293160  [35500/50000]
# loss: 2.300358  [36000/50000]
# loss: 2.307503  [36500/50000]
# loss: 2.296908  [37000/50000]
# loss: 2.304193  [37500/50000]
# loss: 2.293175  [38000/50000]
# loss: 2.301014  [38500/50000]
# loss: 2.310688  [39000/50000]
# loss: 2.302199  [39500/50000]
# loss: 2.318872  [40000/50000]
# loss: 2.311977  [40500/50000]
# loss: 2.313233  [41000/50000]
# loss: 2.288379  [41500/50000]
# loss: 2.306352  [42000/50000]
# loss: 2.318337  [42500/50000]
# loss: 2.289519  [43000/50000]
# loss: 2.303480  [43500/50000]
# loss: 2.319452  [44000/50000]
# loss: 2.295246  [44500/50000]
# loss: 2.320374  [45000/50000]
# loss: 2.286831  [45500/50000]
# loss: 2.295040  [46000/50000]
# loss: 2.277701  [46500/50000]
# loss: 2.292557  [47000/50000]
# loss: 2.318625  [47500/50000]
# loss: 2.295168  [48000/50000]
# loss: 2.289147  [48500/50000]
# loss: 2.296933  [49000/50000]
# loss: 2.300559  [49500/50000]
# Test Error:
#  Accuracy: 10.2%, Avg loss: 2.302652
#
# Done!
